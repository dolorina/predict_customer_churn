# %%
import pandas as pd
import dataframe_image as dfi
pth="~/Desktop/udacity/Course1/Project_Predict_Customer_Churn/predict_customer_churn/data/bank_data.csv"
df = pd.read_csv(pth)

# %%
df.head()
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0           0  768805383  Existing Customer            45      M
# 1           1  818770008  Existing Customer            49      F
# 2           2  713982108  Existing Customer            51      M
# 3           3  769911858  Existing Customer            40      F
# 4           4  709106358  Existing Customer            40      M
#
#    Dependent_count Education_Level Marital_Status Income_Category  \
# 0                3     High School        Married     $60K - $80K
# 1                5        Graduate         Single  Less than $40K
# 2                3        Graduate        Married    $80K - $120K
# 3                4     High School        Unknown  Less than $40K
# 4                3      Uneducated        Married     $60K - $80K
#
#   Card_Category  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0          Blue  ...                       1                      3
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0     CLIENTNUM  Customer_Age  Dependent_count  \
# count  10127.000000  1.012700e+04  10127.000000     10127.000000
# mean    5063.000000  7.391776e+08     46.325960         2.346203
# std     2923.557422  3.690378e+07      8.016814         1.298908
# min        0.000000  7.080821e+08     26.000000         0.000000
# 25%     2531.500000  7.130368e+08     41.000000         1.000000
# 50%     5063.000000  7.179264e+08     46.000000         2.000000
# 75%     7594.500000  7.731435e+08     52.000000         3.000000
# max    10126.000000  8.283431e+08     73.000000         5.000000
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# count    10127.000000              10127.000000            10127.000000
# mean        35.928409                  3.812580                2.341167
# std          7.986416                  1.554408                1.010622
# min         13.000000                  1.000000                0.000000
# ...

# %%
path = r'~/Desktop/udacity/Course1/Project_Predict_Customer_Churn/predict_customer_churn/images/eda/'
dfi.export(df.describe(), path+'df_describe.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-f9c2f12ad85e> in <module>
#       1 path = r'~/Desktop/udacity/Course1/Project_Predict_Customer_Churn/predict_customer_churn/images/eda/'
# ----> 2 dfi.export(df.describe(), path+'df_describe.png')
#
# ~/Desktop/udacity/Course1/.virtualenv/pred_costumer_churn/lib/python3.6/site-packages/dataframe_image/_pandas_accessor.py in export(obj, filename, fontsize, max_rows, max_cols, table_conversion, chrome_path)
#      22 def export(obj, filename, fontsize=14, max_rows=None, max_cols=None,
#      23                table_conversion='chrome', chrome_path=None):
# ---> 24         return _export(obj, filename, fontsize, max_rows, max_cols, table_conversion, chrome_path)
#      25
#      26
#
# ...

# %%
dfi.export(df.head(), path+'df_head.png')

# %%
obj = df.isnull().sum()
columns, index = [], []
for key, val in obj.iteritems():
    index.append(key)
    columns.append(val)

isnull_sum= pd.DataFrame(index=index)
for cols in columns:
    isnull_sum[cols] = pd.Series(dtype=int)
    isnull_sum[cols] = cols

dfi.export(isnull_sum, 'isnull_sum.png')

# %%
isnull_sum
# Out:
#                           0
# Unnamed: 0                0
# CLIENTNUM                 0
# Attrition_Flag            0
# Customer_Age              0
# Gender                    0
# Dependent_count           0
# Education_Level           0
# Marital_Status            0
# Income_Category           0
# Card_Category             0
# Months_on_book            0
# Total_Relationship_Count  0
# Months_Inactive_12_mon    0
# Contacts_Count_12_mon     0
# Credit_Limit              0
# Total_Revolving_Bal       0
# Avg_Open_To_Buy           0
# Total_Amt_Chng_Q4_Q1      0
# Total_Trans_Amt           0
# Total_Trans_Ct            0
# Total_Ct_Chng_Q4_Q1       0
# Avg_Utilization_Ratio     0

# %%
import numpy as np
np.savetxt('isnull_sum.txt', df.isnull().sum())

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')
